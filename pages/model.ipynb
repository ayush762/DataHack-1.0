# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# !unzip  '/content/drive/MyDrive/s4ds/hj3vvx5946-1.zip' -d '/tmp/s4ds'

# %%
train_path = '/tmp/s4ds/hj3vvx5946-1/Splited_dataset/train'
test_path = '/tmp/s4ds/hj3vvx5946-1/Splited_dataset/test'

# %%
folders = glob('/tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/*')

# %%
labels = []
for index,path in enumerate(folders):
  labels.append(path.split('/')[-1])

# %%
len(labels) # this are the labels
# Out:
# 48

# %%
vgg = VGG19(input_shape=(256, 256, 3), weights='imagenet', include_top=False)
# Out:
# ...
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
x = Flatten()(vgg.output)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
import cv2
import os
dest = '/tmp/s4ds/resized'
for path in os.listdir(train_path):
  sub_dir = os.path.join(train_path,path)
  for image in os.listdir(sub_dir):
    img = cv2.imread(os.path.join(sub_dir,image))
    img = cv2.resize(img, (256, 256, 3), interpolation = cv2.INTER_AREA)
# Out:
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Suzuki_cultus_2019
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_premio
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Honda_city_2000
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/FAW_XPV
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Suzuki_Every
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Honda_Vezell
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_corolla_2016
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Daiatsu_Core
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_Aqua
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_Vigo
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Suzuki_cultus_2018
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Suzuki_swift
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Suzuki_alto_japan_2010
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Honda_civic_2018
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_corolla_2000
# /tmp/s4ds/hj3vvx5946-1/Splited_dataset/train/Toyota_Passo
# ...
